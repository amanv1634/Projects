# %%
import pandas as pd
import datetime
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv("P4-Movie-Ratings.csv")

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(df)
# Out:
# 559

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.columns=["Film", "Genre", "CriticRating","AudienceRating","BudgetMillions","Year"]

# %%
df.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
#Year cannot be int64

# %%
df.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
df.Film=df.Film.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
df.Genre=df.Genre.astype('category')
df.Year=df.Year.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
df.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
j = sns.jointplot(data=df, x='CriticRating', y='AudienceRating')

# %%
k = sns.jointplot(data=df, x='CriticRating', y='AudienceRating', kind='hex')

# %%
k = sns.jointplot(data=df, y='BudgetMillions', x='CriticRating', kind='scatter')

# %%
m=sns.distplot(df.AudienceRating)

# %%
n1=sns.distplot(df.CriticRating)

# %%
sns.set_style('darkgrid')
#'white' is used in style to have a plain background
m1=plt.hist(df.AudienceRating)

# %%
m2=plt.hist(df.CriticRating, bins=15)

# %%
h1=plt.hist(df.BudgetMillions)

# %%
drama=df[df.Genre=='Drama']
action=df[df.Genre=='Action']
thriller=df[df.Genre=='thriller']

# %%
drama
# Out:
#                     Film  Genre  CriticRating  AudienceRating  BudgetMillions  \
# 10            88 Minutes  Drama             5              51              30
# 11    A Dangerous Method  Drama            79              89              20
# 13        A Serious Man   Drama            89              64               7
# 18          Albert Nobbs  Drama            53              43               8
# 23       All Good Things  Drama            33              64              20
# ..                   ...    ...           ...             ...             ...
# 529            War Horse  Drama            77              73              66
# 532  Water For Elephants  Drama            60              72              38
# 534     We Own the Night  Drama            55              63              21
# 541             Whip It   Drama            84              73              15
# 545        Winter's Bone  Drama            94              73               2
#
#      Year
# 10   2007
# ...

# %%
drama.BudgetMillions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
plt.hist(action.BudgetMillions, bins=15)
plt.hist(drama.BudgetMillions, bins=15)
plt.show()

# %%
plt.hist([action.BudgetMillions, drama.BudgetMillions], bins=15, stacked=True)
plt.show()

# %%
genrelist=df.Genre.cat.categories
genrelist
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
for gen in genrelist:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=[]
mylabels=[]
for gen in genrelist:
    list1.append(df[df.Genre==gen].BudgetMillions)
    mylabels.append(gen)

# %%
h2=plt.hist(list1, bins=30, stacked=True, rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
vis1 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating', fit_reg=False, hue='Genre', size=7, aspect=1)

# %%
k1=sns.kdeplot(df.CriticRating,df.AudienceRating, shade=True, cmap='Reds')

# %%
k2=sns.kdeplot(df.BudgetMillions,df.AudienceRating)

# %%
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating, shade=True)

# %%
#subplots creates charts for comparison, where 1 denots the number of rows req and 2 denotes the number of columns req
f, axes = plt.subplots(1,2, figsize=(12,6))

# %%
f, axes = plt.subplots(1,2, figsize=(12,6), sharex=True, sharey=True)
k2=sns.kdeplot(df.BudgetMillions,df.AudienceRating, ax=axes[0])
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating, ax=axes[1])
#Setting the x axis limits k1.set(xlim=(-20,160))

# %%
b=sns.boxplot(data=df, x='Genre', y='CriticRating')

# %%
v=sns.violinplot(data=df, x='Genre', y='CriticRating')

# %%
b1=sns.boxplot(data=drama, x='Year',y='CriticRating')

# %%
v1=sns.violinplot(data=drama, x='Year', y='CriticRating')

# %%
#creating a blank facet grid
g = sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')

# %%
g = sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')
g= g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
s = sns.FacetGrid(df,row='Genre',col='Year',hue='Genre',size=50)
s= s.map(plt.hist,'BudgetMillions')

# %%
g = sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')
kws=dict(s=50, linewidth=0.5, edgecolor='black')
g= g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
#controlling axes and adding diagonal
g = sns.FacetGrid(df,row='Genre',col='Year',hue='Genre')
kws=dict(s=50, linewidth=0.5, edgecolor='black')
g= g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100), c="gray", ls="--")
g.add_legend()

# %%
#Building Dashboards

# %%
#we can add only seaborn this way
#if we want to add non seaborn plot we write:
#axes[1,1].hist(df.CriticRating, bins=15)
f, axes= plt.subplots(2,2, figsize=(15,15))
b=sns.boxplot(data=df, x='Genre', y='CriticRating', ax=axes[0,0])
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating, ax=axes[0,1])
v1=sns.violinplot(data=drama, x='Year', y='CriticRating', ax=axes[1,1])
k1=sns.kdeplot(df.CriticRating,df.AudienceRating, shade=True, cmap='Reds', ax=axes[1,0])
k1b=sns.kdeplot(df.CriticRating,df.AudienceRating,cmap='YlGn',ax=axes[1,0])

# %%
#styling Dashboards

# %%
sns.set_style("dark",{"axes.facecolor":"black"})
f, axes= plt.subplots(2,2, figsize=(15,15))
#plot 0,0
b=sns.boxplot(data=df, x='Genre', y='CriticRating', ax=axes[0,0])
#plot 0,1
k3=sns.kdeplot(df.BudgetMillions,df.CriticRating,shade=True,cmap='inferno',shade_lowest=True, ax=axes[0,1])
k3b=sns.kdeplot(df.BudgetMillions,df.CriticRating, cmap='cool', ax=axes[0,1])
#plot 1,0
k1=sns.kdeplot(df.CriticRating,df.AudienceRating, shade=True, cmap='Blues_r', ax=axes[1,0])
k1=sns.kdeplot(df.CriticRating,df.AudienceRating, cmap='gist_gray_r', ax=axes[1,0])
#plot 1,1
v1=sns.violinplot(data=drama, x='Year', y='CriticRating', palette='YlOrRd', ax=axes[1,1])

# %%
#thematic editing
sns.set_style("whitegrid")
fig,ax=plt.subplots()
fig.set_size_inches(11.7,8.27)#A4 Size
h2=plt.hist(list1, bins=30, stacked=True, rwidth=1,label=mylabels)
plt.title("Movie Budget Distribution", fontsize=35, color="DarkBlue", fontname="Console")
plt.ylabel("Number of Movies",fontsize=25,color='Red')
plt.xlabel("BudgetMillions",fontsize=25,color='Green')
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(frameon=True, fancybox=True, shadow=True, framealpha=1,prop={'size':20})
plt.show()
